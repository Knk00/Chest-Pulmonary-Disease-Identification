# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 14, 8

import os
import re

import seaborn as sns
import matplotlib.pyplot as plt
import scipy.misc
import matplotlib


from sklearn.preprocessing import StandardScaler, LabelEncoder
from statsmodels.formula.api import quantreg

# %% [markdown]
# ## Using Multi-Linear Regression:

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

train['test_value'] = 0
test['test_value'] = 1

train = pd.concat( (train, test) )
train.sort_values(['Patient', 'Weeks'], inplace = True)

train.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus  \
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker
#
#    test_value
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# ## Re-formatting Test and Submission dataframes:

# %%
submission['Patient'] = submission['Patient_Week'].map(lambda x: x.split('_')[0])
submission['Weeks'] = submission['Patient_Week'].map(lambda x: x.split('_')[1])

# %%
def encode_and_scale(df):
    le = LabelEncoder()
    df['Sex'] = le.fit_transform(df['Sex'])
    df['SmokingStatus'] = le.fit_transform(df['SmokingStatus'])
    sc = StandardScaler()
    train[['Percent', 'Age', 'Sex', 'SmokingStatus']] = sc.fit_transform(train[['Percent', 'Age', 'Sex', 'SmokingStatus']])
    return df

train = encode_and_scale(train)
train.head()
# Out:
#                      Patient  Weeks   FVC   Percent       Age      Sex  \
# 0  ID00007637202177411956430     -4  2315 -0.981140  1.673414  0.51424
# 1  ID00007637202177411956430      5  2214 -1.109586  1.673414  0.51424
# 2  ID00007637202177411956430      7  2061 -1.304161  1.673414  0.51424
# 3  ID00007637202177411956430      9  2144 -1.198607  1.673414  0.51424
# 4  ID00007637202177411956430     11  2069 -1.293987  1.673414  0.51424
#
#    SmokingStatus  test_value
# 0      -0.423715           0
# 1      -0.423715           0
# 2      -0.423715           0
# 3      -0.423715           0
# 4      -0.423715           0

# %%
# Modelled using statsmodels.formula.api.quant_reg:
modelL = quantreg('FVC ~ Weeks+Percent+Age+Sex+SmokingStatus',
                           train).fit(q = 0.25)
model = quantreg('FVC ~ Weeks+Percent+Age+Sex+SmokingStatus',
                           train).fit(q = 0.5)
modelH = quantreg('FVC ~ Weeks+Percent+Age+Sex+SmokingStatus',
                           train).fit(q = 0.75)
model.summary()
# Out:
# C:\Users\kanis\anaconda3\envs\knk\lib\site-packages\statsmodels\regression\quantile_regression.py:190: IterationLimitWarning: Maximum number of iterations (1000) reached.
#   warnings.warn("Maximum number of iterations (" + str(max_iter) +
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:                    FVC   Pseudo R-squared:               0.6090
# Model:                       QuantReg   Bandwidth:                       121.5
# Method:                 Least Squares   Sparsity:                        654.2
# Date:                Mon, 07 Sep 2020   No. Observations:                 1554
# Time:                        09:52:44   Df Residuals:                     1548
#                                         Df Model:                            5
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      2723.9011     14.105    193.113      0.000    2696.234    2751.568
# Weeks            -0.8102      0.359     -2.258      0.024      -1.514      -0.106
# Percent         641.7857      8.535     75.191      0.000     625.043     658.528
# Age            -115.8960      8.363    -13.858      0.000    -132.300     -99.491
# Sex             429.4419      8.955     47.955      0.000     411.876     447.007
# SmokingStatus    20.4373      8.925      2.290      0.022       2.932      37.943
# =================================================================================
# """

# %%
train['y_predL'] = modelL.predict(train).values
train['y_pred'] = model.predict(train).values
train['y_predH'] = modelH.predict(train).values

#Taking Quartile Deviation to measure confidence:
# train['predSTD'] = 1/2 * np.abs(train['y_predH'], train['y_predL'])

train['predStd'] = 1/2 * (train['y_predH'] - train['y_predL'])
train.head(10)
# Out:
#                      Patient  Weeks   FVC   Percent       Age      Sex  \
# 0  ID00007637202177411956430     -4  2315 -0.981140  1.673414  0.51424
# 1  ID00007637202177411956430      5  2214 -1.109586  1.673414  0.51424
# 2  ID00007637202177411956430      7  2061 -1.304161  1.673414  0.51424
# 3  ID00007637202177411956430      9  2144 -1.198607  1.673414  0.51424
# 4  ID00007637202177411956430     11  2069 -1.293987  1.673414  0.51424
# 5  ID00007637202177411956430     17  2101 -1.253292  1.673414  0.51424
# 6  ID00007637202177411956430     29  2000 -1.381737  1.673414  0.51424
# 7  ID00007637202177411956430     41  2064 -1.300346  1.673414  0.51424
# 8  ID00007637202177411956430     57  2057 -1.309248  1.673414  0.51424
# 9  ID00009637202177434476278      8  3660  0.384884  0.254864  0.51424
#
#    SmokingStatus  test_value      y_predL       y_pred      y_predH  \
# 0      -0.423715           0  1929.933801  2115.694765  2268.520495
# 1      -0.423715           0  1849.393889  2025.968534  2181.002372
# 2      -0.423715           0  1732.496086  1899.472326  2047.633026
# 3      -0.423715           0  1794.556661  1965.594982  2120.193839
# 4      -0.423715           0  1736.806119  1902.760941  2054.886156
# 5      -0.423715           0  1758.437133  1924.017495  2083.217559
# 6      -0.423715           0  1676.579955  1831.860636  1995.903771
# 7      -0.423715           0  1719.841983  1874.373745  2052.566578
# 8      -0.423715           0  1707.508485  1855.697120  2047.548267
# 9      -0.423715           0  2933.744104  3147.071034  3370.709145
#
#       predStd
# 0  169.293347
# 1  165.804242
# 2  157.568470
# 3  162.818589
# 4  159.040019
# 5  162.390213
# 6  159.661908
# 7  166.362298
# 8  170.019891
# 9  218.482520

# %%
def compute_metric(trueFVC, predFVC, predStd):
    clipSTD = np.maximum(predStd, 70)
    delta = np.minimum(np.abs(trueFVC, predFVC), 1000)
    metric = -(np.sqrt(2) * delta / clipSTD) - np.log(np.sqrt(2) * clipSTD)  
    return metric

# %%
print('Metric:', compute_metric(train['FVC'].values, train['y_pred'].values, train['predStd'].values).mean())
# Out:
# Metric: -13.0008946634282

# %%
test.shape
# Out:
# (5, 8)

# %%
submission
# Out:
#                       Patient_Week   FVC  Confidence  \
# 0    ID00419637202311204720264_-12  2000         100
# 1    ID00421637202311550012437_-12  2000         100
# 2    ID00422637202311677017371_-12  2000         100
# 3    ID00423637202312137826377_-12  2000         100
# 4    ID00426637202313170790466_-12  2000         100
# ..                             ...   ...         ...
# 725  ID00419637202311204720264_133  2000         100
# 726  ID00421637202311550012437_133  2000         100
# 727  ID00422637202311677017371_133  2000         100
# 728  ID00423637202312137826377_133  2000         100
# 729  ID00426637202313170790466_133  2000         100
#
#                        Patient Weeks
# 0    ID00419637202311204720264   -12
# 1    ID00421637202311550012437   -12
# 2    ID00422637202311677017371   -12
# 3    ID00423637202312137826377   -12
# 4    ID00426637202313170790466   -12
# ..                         ...   ...
# 725  ID00419637202311204720264   133
# 726  ID00421637202311550012437   133
# 727  ID00422637202311677017371   133
# 728  ID00423637202312137826377   133
# 729  ID00426637202313170790466   133
#
# [730 rows x 5 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Patient        5 non-null      object
#  1   Weeks          5 non-null      int64
#  2   FVC            5 non-null      int64
#  3   Percent        5 non-null      float64
#  4   Age            5 non-null      int64
#  5   Sex            5 non-null      object
#  6   SmokingStatus  5 non-null      object
#  7   test_value     5 non-null      int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 448.0+ bytes

# %%
submission
# Out:
#                       Patient_Week   FVC  Confidence  \
# 0    ID00419637202311204720264_-12  2000         100
# 1    ID00421637202311550012437_-12  2000         100
# 2    ID00422637202311677017371_-12  2000         100
# 3    ID00423637202312137826377_-12  2000         100
# 4    ID00426637202313170790466_-12  2000         100
# ..                             ...   ...         ...
# 725  ID00419637202311204720264_133  2000         100
# 726  ID00421637202311550012437_133  2000         100
# 727  ID00422637202311677017371_133  2000         100
# 728  ID00423637202312137826377_133  2000         100
# 729  ID00426637202313170790466_133  2000         100
#
#                        Patient Weeks
# 0    ID00419637202311204720264   -12
# 1    ID00421637202311550012437   -12
# 2    ID00422637202311677017371   -12
# 3    ID00423637202312137826377   -12
# 4    ID00426637202313170790466   -12
# ..                         ...   ...
# 725  ID00419637202311204720264   133
# 726  ID00421637202311550012437   133
# 727  ID00422637202311677017371   133
# 728  ID00423637202312137826377   133
# 729  ID00426637202313170790466   133
#
# [730 rows x 5 columns]

# %%
submission.describe()
# Out:
#           FVC  Confidence
# count   730.0       730.0
# mean   2000.0       100.0
# std       0.0         0.0
# min    2000.0       100.0
# 25%    2000.0       100.0
# 50%    2000.0       100.0
# 75%    2000.0       100.0
# max    2000.0       100.0

# %%
test = encode_and_scale(test)
dt = train.loc[train.test_value == 1, ['Patient','Percent','Age','Sex','SmokingStatus']]
test = pd.merge(submission, dt, on='Patient', how='left')

# %%
test
# Out:
#                       Patient_Week   FVC  Confidence  \
# 0    ID00419637202311204720264_-12  2000         100
# 1    ID00421637202311550012437_-12  2000         100
# 2    ID00422637202311677017371_-12  2000         100
# 3    ID00423637202312137826377_-12  2000         100
# 4    ID00426637202313170790466_-12  2000         100
# ..                             ...   ...         ...
# 725  ID00419637202311204720264_133  2000         100
# 726  ID00421637202311550012437_133  2000         100
# 727  ID00422637202311677017371_133  2000         100
# 728  ID00423637202312137826377_133  2000         100
# 729  ID00426637202313170790466_133  2000         100
#
#                        Patient Weeks   Percent       Age      Sex  \
# 0    ID00419637202311204720264   -12 -0.378051  0.822284  0.51424
# 1    ID00421637202311550012437   -12  0.221260  0.113009  0.51424
# 2    ID00422637202311677017371   -12 -0.050275  0.822284  0.51424
# 3    ID00423637202312137826377   -12  0.080439  0.680429  0.51424
# 4    ID00426637202313170790466   -12 -0.295262  0.822284  0.51424
# ..                         ...   ...       ...       ...      ...
# 725  ID00419637202311204720264   133 -0.378051  0.822284  0.51424
# 726  ID00421637202311550012437   133  0.221260  0.113009  0.51424
# 727  ID00422637202311677017371   133 -0.050275  0.822284  0.51424
# 728  ID00423637202312137826377   133  0.080439  0.680429  0.51424
# 729  ID00426637202313170790466   133 -0.295262  0.822284  0.51424
#
#      SmokingStatus
# 0        -0.423715
# 1        -0.423715
# 2        -0.423715
# 3        -0.423715
# 4         1.468393
# ..             ...
# 725      -0.423715
# 726      -0.423715
# 727      -0.423715
# 728      -0.423715
# 729       1.468393
#
# [730 rows x 9 columns]

# %%
df = test.copy()
df['Weeks'] = df['Weeks'].astype('int')
df.sort_values(['Patient', 'Weeks'], inplace=True)

# %%
df
# Out:
#                       Patient_Week   FVC  Confidence  \
# 0    ID00419637202311204720264_-12  2000         100
# 5    ID00419637202311204720264_-11  2000         100
# 10   ID00419637202311204720264_-10  2000         100
# 15    ID00419637202311204720264_-9  2000         100
# 20    ID00419637202311204720264_-8  2000         100
# ..                             ...   ...         ...
# 709  ID00426637202313170790466_129  2000         100
# 714  ID00426637202313170790466_130  2000         100
# 719  ID00426637202313170790466_131  2000         100
# 724  ID00426637202313170790466_132  2000         100
# 729  ID00426637202313170790466_133  2000         100
#
#                        Patient  Weeks   Percent       Age      Sex  \
# 0    ID00419637202311204720264    -12 -0.378051  0.822284  0.51424
# 5    ID00419637202311204720264    -11 -0.378051  0.822284  0.51424
# 10   ID00419637202311204720264    -10 -0.378051  0.822284  0.51424
# 15   ID00419637202311204720264     -9 -0.378051  0.822284  0.51424
# 20   ID00419637202311204720264     -8 -0.378051  0.822284  0.51424
# ..                         ...    ...       ...       ...      ...
# 709  ID00426637202313170790466    129 -0.295262  0.822284  0.51424
# 714  ID00426637202313170790466    130 -0.295262  0.822284  0.51424
# 719  ID00426637202313170790466    131 -0.295262  0.822284  0.51424
# 724  ID00426637202313170790466    132 -0.295262  0.822284  0.51424
# 729  ID00426637202313170790466    133 -0.295262  0.822284  0.51424
#
#      SmokingStatus
# 0        -0.423715
# 5        -0.423715
# 10       -0.423715
# 15       -0.423715
# 20       -0.423715
# ..             ...
# 709       1.468393
# 714       1.468393
# 719       1.468393
# 724       1.468393
# 729       1.468393
#
# [730 rows x 9 columns]

# %%
df['ypredL'] = modelL.predict( df ).values
df['FVC']    = model.predict( df ).values
df['ypredH'] = modelH.predict( df ).values
df['Confidence'] = np.abs(df['ypredH'] - df['ypredL']) / 2

# %%
df
# Out:
#                       Patient_Week          FVC  Confidence  \
# 0    ID00419637202311204720264_-12  2607.873178  185.222901
# 5    ID00419637202311204720264_-11  2607.062968  185.476501
# 10   ID00419637202311204720264_-10  2606.252759  185.730100
# 15    ID00419637202311204720264_-9  2605.442549  185.983700
# 20    ID00419637202311204720264_-8  2604.632340  186.237300
# ..                             ...          ...         ...
# 709  ID00426637202313170790466_129  2585.435569  212.613773
# 714  ID00426637202313170790466_130  2584.625360  212.867373
# 719  ID00426637202313170790466_131  2583.815150  213.120973
# 724  ID00426637202313170790466_132  2583.004940  213.374573
# 729  ID00426637202313170790466_133  2582.194731  213.628173
#
#                        Patient  Weeks   Percent       Age      Sex  \
# 0    ID00419637202311204720264    -12 -0.378051  0.822284  0.51424
# 5    ID00419637202311204720264    -11 -0.378051  0.822284  0.51424
# 10   ID00419637202311204720264    -10 -0.378051  0.822284  0.51424
# 15   ID00419637202311204720264     -9 -0.378051  0.822284  0.51424
# 20   ID00419637202311204720264     -8 -0.378051  0.822284  0.51424
# ..                         ...    ...       ...       ...      ...
# 709  ID00426637202313170790466    129 -0.295262  0.822284  0.51424
# 714  ID00426637202313170790466    130 -0.295262  0.822284  0.51424
# 719  ID00426637202313170790466    131 -0.295262  0.822284  0.51424
# 724  ID00426637202313170790466    132 -0.295262  0.822284  0.51424
# 729  ID00426637202313170790466    133 -0.295262  0.822284  0.51424
#
#      SmokingStatus       ypredL       ypredH
# 0        -0.423715  2409.786780  2780.232581
# 5        -0.423715  2409.347692  2780.300693
# 10       -0.423715  2408.908604  2780.368805
# 15       -0.423715  2408.469516  2780.436916
# 20       -0.423715  2408.030427  2780.505028
# ..             ...          ...          ...
# 709       1.468393  2450.837162  2876.064709
# 714       1.468393  2450.398074  2876.132821
# 719       1.468393  2449.958986  2876.200932
# 724       1.468393  2449.519898  2876.269044
# 729       1.468393  2449.080810  2876.337156
#
# [730 rows x 11 columns]

# %%
df[['Patient_Week', 'FVC', 'Confidence']].to_csv('Submission.csv')
